# %% [markdown]
# Heroes Of Pymoli Data Analysis
# ============================

# %% [markdown]
# analysis

# %%
#import modules

import pandas as pd

# %%
input_path = "../Resources/purchase_data.csv"

# %%
purchase_data = pd.read_csv(input_path, index_col="Purchase ID")

# %%
## setting formatting for dataframe output

###header formatting
heading_format = [
  ('font-size', '14px'),
  ('text-align', 'Left'),
  ('font-weight', 'bold'),
  ('background-color', '#CFCFCF')]

###body formatting
element_format = [('font-size', '13px'), 
                  ('text-align', 'Left')]

###caption formatting

caption_element = [
  ('font-size', '15px'),
  ('text-align', 'center'),
  ('font-weight', 'bold')]

### put it together
styles = [dict(selector="th", props=heading_format),
          dict(selector="td", props=element_format),  
          dict(selector="caption", props=caption_element)]

# %% [markdown]
# ---
#
# Player Count
# ------------------------

# %%
## Player Count

### pull Total Number of Players

no_of_players = purchase_data["SN"].nunique()

### insert output in dataframe for display

player_df = pd.DataFrame({"Total Players" : [no_of_players]})
    
player_df.style.set_caption("Total Number of Players"
              ).set_table_styles(styles
              ).hide_index()
# Out:
# <style  type="text/css" >
#     #T_1703c440_aabf_11ea_933e_84a93e4c419e th {
#           font-size: 14px;
#           text-align: Left;
#           font-weight: bold;
#           background-color: #CFCFCF;
#     }    #T_1703c440_aabf_11ea_933e_84a93e4c419e td {
#           font-size: 13px;
#           text-align: Left;
#     }    #T_1703c440_aabf_11ea_933e_84a93e4c419e caption {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#     }</style><table id="T_1703c440_aabf_11ea_933e_84a93e4c419e" ><caption>Total Number of Players</caption><thead>    <tr>        <th class="col_heading level0 col0" >Total Players</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_1703c440_aabf_11ea_933e_84a93e4c419erow0_col0" class="data row0 col0" >576</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ---
#
# Purchasing Analysis (Total)
# ------------------------

# %%
## Purchasing Analysis (Total)

### determine number of unique items

unique_items = purchase_data.groupby("Item Name")

no_unique_items = len(unique_items)

### determine average price

average_purchase_price = purchase_data["Price"].mean()

### determine total no of purchases

total_no_purchases = sum(purchase_data["Price"].value_counts())

### determine total revenue

total_revenue = sum(purchase_data["Price"])

### insert output in dataframe for display, including formatting

item_df = pd.DataFrame({
    
    "Number of Unique Items" : [no_unique_items], 
    "Average Price" : [average_purchase_price], 
    "Number of Purchases" : [total_no_purchases], 
    "Total Revenue" : [total_revenue]})
    
item_df.style.set_caption("Purchasing Analysis of Total Players"
            ).format({"Average Price": "${:,.2f}", 
                      "Total Revenue": "${:,.2f}"}
            ).set_table_styles(styles
            ).hide_index()
# Out:
# <style  type="text/css" >
#     #T_18c4b974_aabf_11ea_9813_84a93e4c419e th {
#           font-size: 14px;
#           text-align: Left;
#           font-weight: bold;
#           background-color: #CFCFCF;
#     }    #T_18c4b974_aabf_11ea_9813_84a93e4c419e td {
#           font-size: 13px;
#           text-align: Left;
#     }    #T_18c4b974_aabf_11ea_9813_84a93e4c419e caption {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#     }</style><table id="T_18c4b974_aabf_11ea_9813_84a93e4c419e" ><caption>Purchasing Analysis of Total Players</caption><thead>    <tr>        <th class="col_heading level0 col0" >Number of Unique Items</th>        <th class="col_heading level0 col1" >Average Price</th>        <th class="col_heading level0 col2" >Number of Purchases</th>        <th class="col_heading level0 col3" >Total Revenue</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_18c4b974_aabf_11ea_9813_84a93e4c419erow0_col0" class="data row0 col0" >179</td>
#                         <td id="T_18c4b974_aabf_11ea_9813_84a93e4c419erow0_col1" class="data row0 col1" >$3.05</td>
#                         <td id="T_18c4b974_aabf_11ea_9813_84a93e4c419erow0_col2" class="data row0 col2" >780</td>
#                         <td id="T_18c4b974_aabf_11ea_9813_84a93e4c419erow0_col3" class="data row0 col3" >$2,379.77</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ---
#
# Gender Demographics
# ------------------------

# %%
## Gender Demographics

### create new dataframe stratified by gender

gender_strat_data = purchase_data.groupby("Gender")

### determine counts by gender

gender_counts = gender_strat_data["SN"].nunique()

### insert column for percentage by gender

gender_percent = gender_strat_data["SN"].nunique()/sum(gender_strat_data["SN"].nunique())

###Display Percentage and Count of Players by Gender, including formatting

gender_total_df = pd.DataFrame({
                                "Total Count" : gender_counts, 
                                "Percentage of Players" : gender_percent})

gender_total_df_sorted = gender_total_df.sort_values("Percentage of Players", ascending = False)

gender_total_df_sorted.style.set_caption("Gender Demograpics"
                            ).format({"Percentage of Players": "{:,.2%}"}
                            ).set_table_styles(styles)
# Out:
# <style  type="text/css" >
#     #T_197c6dfa_aabf_11ea_8f0c_84a93e4c419e th {
#           font-size: 14px;
#           text-align: Left;
#           font-weight: bold;
#           background-color: #CFCFCF;
#     }    #T_197c6dfa_aabf_11ea_8f0c_84a93e4c419e td {
#           font-size: 13px;
#           text-align: Left;
#     }    #T_197c6dfa_aabf_11ea_8f0c_84a93e4c419e caption {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#     }</style><table id="T_197c6dfa_aabf_11ea_8f0c_84a93e4c419e" ><caption>Gender Demograpics</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_197c6dfa_aabf_11ea_8f0c_84a93e4c419elevel0_row0" class="row_heading level0 row0" >Male</th>
#                         <td id="T_197c6dfa_aabf_11ea_8f0c_84a93e4c419erow0_col0" class="data row0 col0" >484</td>
#                         <td id="T_197c6dfa_aabf_11ea_8f0c_84a93e4c419erow0_col1" class="data row0 col1" >84.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_197c6dfa_aabf_11ea_8f0c_84a93e4c419elevel0_row1" class="row_heading level0 row1" >Female</th>
#                         <td id="T_197c6dfa_aabf_11ea_8f0c_84a93e4c419erow1_col0" class="data row1 col0" >81</td>
#                         <td id="T_197c6dfa_aabf_11ea_8f0c_84a93e4c419erow1_col1" class="data row1 col1" >14.06%</td>
#             </tr>
#             <tr>
#                         <th id="T_197c6dfa_aabf_11ea_8f0c_84a93e4c419elevel0_row2" class="row_heading level0 row2" >Other / Non-Disclosed</th>
#                         <td id="T_197c6dfa_aabf_11ea_8f0c_84a93e4c419erow2_col0" class="data row2 col0" >11</td>
#                         <td id="T_197c6dfa_aabf_11ea_8f0c_84a93e4c419erow2_col1" class="data row2 col1" >1.91%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ---
#
# Purchasing Analysis (Gender)
# ------------------------

# %%
## Purchasing Analysis(Gender)

### pull purchase count

purchase_count_gender = gender_strat_data["Item Name"].count()

### pull average purchase price

purchase_average_price_gender = gender_strat_data["Price"].mean()

### pull total purchase value

total_purchase_gender = gender_strat_data["Price"].sum()

### pull average total purchase per person

average_total_purchase_gender = total_purchase_gender/gender_strat_data["SN"].nunique()

### Display Gender Analysis, including formatting

gender_analysis = pd.DataFrame({"Purchase Count" : purchase_count_gender, 
                                "Average Purchase Price" : purchase_average_price_gender,
                                "Total Purchase Value" : total_purchase_gender,
                                "Avg Total Purchase per Person" : average_total_purchase_gender})

gender_analysis_sorted = gender_analysis.sort_values(
                                            "Avg Total Purchase per Person", ascending = False)

gender_analysis_sorted.style.format({
                             "Average Purchase Price" : "${:,.2f}", 
                              "Total Purchase Value" : "${:,.2f}", 
                              "Avg Total Purchase per Person" : "${:,.2f}"}
                            ).set_caption("Purchasing Analysis by Gender"
                            ).set_table_styles(styles)
# Out:
# <style  type="text/css" >
#     #T_24917586_aabf_11ea_8ce2_84a93e4c419e th {
#           font-size: 14px;
#           text-align: Left;
#           font-weight: bold;
#           background-color: #CFCFCF;
#     }    #T_24917586_aabf_11ea_8ce2_84a93e4c419e td {
#           font-size: 13px;
#           text-align: Left;
#     }    #T_24917586_aabf_11ea_8ce2_84a93e4c419e caption {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#     }</style><table id="T_24917586_aabf_11ea_8ce2_84a93e4c419e" ><caption>Purchasing Analysis by Gender</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>        <th class="col_heading level0 col3" >Avg Total Purchase per Person</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_24917586_aabf_11ea_8ce2_84a93e4c419elevel0_row0" class="row_heading level0 row0" >Other / Non-Disclosed</th>
#                         <td id="T_24917586_aabf_11ea_8ce2_84a93e4c419erow0_col0" class="data row0 col0" >15</td>
#                         <td id="T_24917586_aabf_11ea_8ce2_84a93e4c419erow0_col1" class="data row0 col1" >$3.35</td>
#                         <td id="T_24917586_aabf_11ea_8ce2_84a93e4c419erow0_col2" class="data row0 col2" >$50.19</td>
#                         <td id="T_24917586_aabf_11ea_8ce2_84a93e4c419erow0_col3" class="data row0 col3" >$4.56</td>
#             </tr>
#             <tr>
#                         <th id="T_24917586_aabf_11ea_8ce2_84a93e4c419elevel0_row1" class="row_heading level0 row1" >Female</th>
#                         <td id="T_24917586_aabf_11ea_8ce2_84a93e4c419erow1_col0" class="data row1 col0" >113</td>
#                         <td id="T_24917586_aabf_11ea_8ce2_84a93e4c419erow1_col1" class="data row1 col1" >$3.20</td>
#                         <td id="T_24917586_aabf_11ea_8ce2_84a93e4c419erow1_col2" class="data row1 col2" >$361.94</td>
#                         <td id="T_24917586_aabf_11ea_8ce2_84a93e4c419erow1_col3" class="data row1 col3" >$4.47</td>
#             </tr>
#             <tr>
#                         <th id="T_24917586_aabf_11ea_8ce2_84a93e4c419elevel0_row2" class="row_heading level0 row2" >Male</th>
#                         <td id="T_24917586_aabf_11ea_8ce2_84a93e4c419erow2_col0" class="data row2 col0" >652</td>
#                         <td id="T_24917586_aabf_11ea_8ce2_84a93e4c419erow2_col1" class="data row2 col1" >$3.02</td>
#                         <td id="T_24917586_aabf_11ea_8ce2_84a93e4c419erow2_col2" class="data row2 col2" >$1,967.64</td>
#                         <td id="T_24917586_aabf_11ea_8ce2_84a93e4c419erow2_col3" class="data row2 col3" >$4.07</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ---
#
# Age Demographics
# ------------------------

# %%
## Age Demographics

#create and implement age bins

age_bins = [0, 9, 14, 19, 24, 29, 34, 39, 100]
age_labels = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

age_df = purchase_data

age_df["Age Group"] = pd.cut(age_df["Age"], age_bins, labels=age_labels, include_lowest=True)

age_strat_data = age_df.groupby("Age Group")

### determine counts by age

age_counts = age_strat_data["SN"].nunique()

#age_counts.columns =["Total Count"]

### insert column for percentage by gender

age_percent = age_strat_data["SN"].nunique()/sum(age_strat_data["SN"].nunique())

###Display Percentage and Count of Players by age, including formatting

age_total_df = pd.DataFrame({"Total Count" : age_counts, 
                             "Percentage of Players" : age_percent})

age_total_df.style.set_caption("Age Demographics"
                 ).format ({"Percentage of Players" : "{:,.2%}"}
                 ).set_table_styles(styles)
# Out:
# <style  type="text/css" >
#     #T_45379934_aabf_11ea_b935_84a93e4c419e th {
#           font-size: 14px;
#           text-align: Left;
#           font-weight: bold;
#           background-color: #CFCFCF;
#     }    #T_45379934_aabf_11ea_b935_84a93e4c419e td {
#           font-size: 13px;
#           text-align: Left;
#     }    #T_45379934_aabf_11ea_b935_84a93e4c419e caption {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#     }</style><table id="T_45379934_aabf_11ea_b935_84a93e4c419e" ><caption>Age Demographics</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr>    <tr>        <th class="index_name level0" >Age Group</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_45379934_aabf_11ea_b935_84a93e4c419elevel0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_45379934_aabf_11ea_b935_84a93e4c419erow0_col0" class="data row0 col0" >17</td>
#                         <td id="T_45379934_aabf_11ea_b935_84a93e4c419erow0_col1" class="data row0 col1" >2.95%</td>
#             </tr>
#             <tr>
#                         <th id="T_45379934_aabf_11ea_b935_84a93e4c419elevel0_row1" class="row_heading level0 row1" >10-14</th>
#                         <td id="T_45379934_aabf_11ea_b935_84a93e4c419erow1_col0" class="data row1 col0" >22</td>
#                         <td id="T_45379934_aabf_11ea_b935_84a93e4c419erow1_col1" class="data row1 col1" >3.82%</td>
#             </tr>
#             <tr>
#                         <th id="T_45379934_aabf_11ea_b935_84a93e4c419elevel0_row2" class="row_heading level0 row2" >15-19</th>
#                         <td id="T_45379934_aabf_11ea_b935_84a93e4c419erow2_col0" class="data row2 col0" >107</td>
#                         <td id="T_45379934_aabf_11ea_b935_84a93e4c419erow2_col1" class="data row2 col1" >18.58%</td>
#             </tr>
#             <tr>
#                         <th id="T_45379934_aabf_11ea_b935_84a93e4c419elevel0_row3" class="row_heading level0 row3" >20-24</th>
#                         <td id="T_45379934_aabf_11ea_b935_84a93e4c419erow3_col0" class="data row3 col0" >258</td>
#                         <td id="T_45379934_aabf_11ea_b935_84a93e4c419erow3_col1" class="data row3 col1" >44.79%</td>
#             </tr>
#             <tr>
#                         <th id="T_45379934_aabf_11ea_b935_84a93e4c419elevel0_row4" class="row_heading level0 row4" >25-29</th>
#                         <td id="T_45379934_aabf_11ea_b935_84a93e4c419erow4_col0" class="data row4 col0" >77</td>
#                         <td id="T_45379934_aabf_11ea_b935_84a93e4c419erow4_col1" class="data row4 col1" >13.37%</td>
#             </tr>
#             <tr>
#                         <th id="T_45379934_aabf_11ea_b935_84a93e4c419elevel0_row5" class="row_heading level0 row5" >30-34</th>
#                         <td id="T_45379934_aabf_11ea_b935_84a93e4c419erow5_col0" class="data row5 col0" >52</td>
#                         <td id="T_45379934_aabf_11ea_b935_84a93e4c419erow5_col1" class="data row5 col1" >9.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_45379934_aabf_11ea_b935_84a93e4c419elevel0_row6" class="row_heading level0 row6" >35-39</th>
#                         <td id="T_45379934_aabf_11ea_b935_84a93e4c419erow6_col0" class="data row6 col0" >31</td>
#                         <td id="T_45379934_aabf_11ea_b935_84a93e4c419erow6_col1" class="data row6 col1" >5.38%</td>
#             </tr>
#             <tr>
#                         <th id="T_45379934_aabf_11ea_b935_84a93e4c419elevel0_row7" class="row_heading level0 row7" >40+</th>
#                         <td id="T_45379934_aabf_11ea_b935_84a93e4c419erow7_col0" class="data row7 col0" >12</td>
#                         <td id="T_45379934_aabf_11ea_b935_84a93e4c419erow7_col1" class="data row7 col1" >2.08%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ---
#
# Purchasing Analysis (Age)
# ------------------------

# %%
## Purchasing Analysis(Age)

### pull purchase count

purchase_count_age = age_strat_data["Item Name"].count()

### pull average purchase price

purchase_average_price_age = age_strat_data["Price"].mean()

### pull total purchase value

total_purchase_age = age_strat_data["Price"].sum()

### pull average total purchase per person

average_total_purchase_age = total_purchase_age/age_strat_data["SN"].nunique()

### Display Gender Analysis, including formatting

age_analysis = pd.DataFrame({"Purchase Count" : purchase_count_age, 
                            "Average Purchase Price" : purchase_average_price_age,
                            "Total Purchase Value" : total_purchase_age,
                            "Avg Total Purchase per Person" : average_total_purchase_age})

age_analysis.style.set_caption(
                            "Purchasing Analysis by Age Group"
                    ).format({"Average Purchase Price" : "${:,.2f}", 
                              "Total Purchase Value" : "${:,.2f}", 
                              "Avg Total Purchase per Person" : "${:,.2f}"}
                    ).set_table_styles(styles)
# Out:
# <style  type="text/css" >
#     #T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419e th {
#           font-size: 14px;
#           text-align: Left;
#           font-weight: bold;
#           background-color: #CFCFCF;
#     }    #T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419e td {
#           font-size: 13px;
#           text-align: Left;
#     }    #T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419e caption {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#     }</style><table id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419e" ><caption>Purchasing Analysis by Age Group</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>        <th class="col_heading level0 col3" >Avg Total Purchase per Person</th>    </tr>    <tr>        <th class="index_name level0" >Age Group</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419elevel0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow0_col0" class="data row0 col0" >23</td>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow0_col1" class="data row0 col1" >$3.35</td>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow0_col2" class="data row0 col2" >$77.13</td>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow0_col3" class="data row0 col3" >$4.54</td>
#             </tr>
#             <tr>
#                         <th id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419elevel0_row1" class="row_heading level0 row1" >10-14</th>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow1_col0" class="data row1 col0" >28</td>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow1_col1" class="data row1 col1" >$2.96</td>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow1_col2" class="data row1 col2" >$82.78</td>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow1_col3" class="data row1 col3" >$3.76</td>
#             </tr>
#             <tr>
#                         <th id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419elevel0_row2" class="row_heading level0 row2" >15-19</th>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow2_col0" class="data row2 col0" >136</td>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow2_col1" class="data row2 col1" >$3.04</td>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow2_col2" class="data row2 col2" >$412.89</td>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow2_col3" class="data row2 col3" >$3.86</td>
#             </tr>
#             <tr>
#                         <th id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419elevel0_row3" class="row_heading level0 row3" >20-24</th>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow3_col0" class="data row3 col0" >365</td>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow3_col1" class="data row3 col1" >$3.05</td>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow3_col2" class="data row3 col2" >$1,114.06</td>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow3_col3" class="data row3 col3" >$4.32</td>
#             </tr>
#             <tr>
#                         <th id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419elevel0_row4" class="row_heading level0 row4" >25-29</th>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow4_col0" class="data row4 col0" >101</td>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow4_col1" class="data row4 col1" >$2.90</td>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow4_col2" class="data row4 col2" >$293.00</td>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow4_col3" class="data row4 col3" >$3.81</td>
#             </tr>
#             <tr>
#                         <th id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419elevel0_row5" class="row_heading level0 row5" >30-34</th>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow5_col0" class="data row5 col0" >73</td>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow5_col1" class="data row5 col1" >$2.93</td>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow5_col2" class="data row5 col2" >$214.00</td>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow5_col3" class="data row5 col3" >$4.12</td>
#             </tr>
#             <tr>
#                         <th id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419elevel0_row6" class="row_heading level0 row6" >35-39</th>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow6_col0" class="data row6 col0" >41</td>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow6_col1" class="data row6 col1" >$3.60</td>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow6_col2" class="data row6 col2" >$147.67</td>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow6_col3" class="data row6 col3" >$4.76</td>
#             </tr>
#             <tr>
#                         <th id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419elevel0_row7" class="row_heading level0 row7" >40+</th>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow7_col0" class="data row7 col0" >13</td>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow7_col1" class="data row7 col1" >$2.94</td>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow7_col2" class="data row7 col2" >$38.24</td>
#                         <td id="T_8b9aa5a4_aabf_11ea_8b49_84a93e4c419erow7_col3" class="data row7 col3" >$3.19</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ---
#
# Top Spenders
# ------------------------

# %%
## Top Spenders

### create new dataframe stratified by SN

SN_strat_data = purchase_data.groupby("SN")

### pull purchase count

purchase_count_SN = SN_strat_data["Item Name"].count()

### pull average purchase price

purchase_average_price_SN = SN_strat_data["Price"].mean()

### pull total purchase value

total_purchase_SN = SN_strat_data["Price"].sum()

### Create dataframe

SN_analysis = pd.DataFrame({"Purchase Count" : purchase_count_SN, 
                            "Average Purchase Price" : purchase_average_price_SN,
                            "Total Purchase Value" : total_purchase_SN})
### sort       
SN_analysis_sorted = SN_analysis.sort_values("Total Purchase Value", ascending = False)

### select top spenders

top_spenders = SN_analysis_sorted.iloc[0:5, :]

### format output

top_spenders.style.set_caption("Top Five Players by Total Purchase Value"
                 ).format({
                            "Average Purchase Price" : "${:,.2f}", 
                            "Total Purchase Value" : "${:,.2f}"}
                 ).set_table_styles(styles)
# Out:
# <style  type="text/css" >
#     #T_b338c588_aabf_11ea_9ed1_84a93e4c419e th {
#           font-size: 14px;
#           text-align: Left;
#           font-weight: bold;
#           background-color: #CFCFCF;
#     }    #T_b338c588_aabf_11ea_9ed1_84a93e4c419e td {
#           font-size: 13px;
#           text-align: Left;
#     }    #T_b338c588_aabf_11ea_9ed1_84a93e4c419e caption {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#     }</style><table id="T_b338c588_aabf_11ea_9ed1_84a93e4c419e" ><caption>Top Five Players by Total Purchase Value</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >SN</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b338c588_aabf_11ea_9ed1_84a93e4c419elevel0_row0" class="row_heading level0 row0" >Lisosia93</th>
#                         <td id="T_b338c588_aabf_11ea_9ed1_84a93e4c419erow0_col0" class="data row0 col0" >5</td>
#                         <td id="T_b338c588_aabf_11ea_9ed1_84a93e4c419erow0_col1" class="data row0 col1" >$3.79</td>
#                         <td id="T_b338c588_aabf_11ea_9ed1_84a93e4c419erow0_col2" class="data row0 col2" >$18.96</td>
#             </tr>
#             <tr>
#                         <th id="T_b338c588_aabf_11ea_9ed1_84a93e4c419elevel0_row1" class="row_heading level0 row1" >Idastidru52</th>
#                         <td id="T_b338c588_aabf_11ea_9ed1_84a93e4c419erow1_col0" class="data row1 col0" >4</td>
#                         <td id="T_b338c588_aabf_11ea_9ed1_84a93e4c419erow1_col1" class="data row1 col1" >$3.86</td>
#                         <td id="T_b338c588_aabf_11ea_9ed1_84a93e4c419erow1_col2" class="data row1 col2" >$15.45</td>
#             </tr>
#             <tr>
#                         <th id="T_b338c588_aabf_11ea_9ed1_84a93e4c419elevel0_row2" class="row_heading level0 row2" >Chamjask73</th>
#                         <td id="T_b338c588_aabf_11ea_9ed1_84a93e4c419erow2_col0" class="data row2 col0" >3</td>
#                         <td id="T_b338c588_aabf_11ea_9ed1_84a93e4c419erow2_col1" class="data row2 col1" >$4.61</td>
#                         <td id="T_b338c588_aabf_11ea_9ed1_84a93e4c419erow2_col2" class="data row2 col2" >$13.83</td>
#             </tr>
#             <tr>
#                         <th id="T_b338c588_aabf_11ea_9ed1_84a93e4c419elevel0_row3" class="row_heading level0 row3" >Iral74</th>
#                         <td id="T_b338c588_aabf_11ea_9ed1_84a93e4c419erow3_col0" class="data row3 col0" >4</td>
#                         <td id="T_b338c588_aabf_11ea_9ed1_84a93e4c419erow3_col1" class="data row3 col1" >$3.40</td>
#                         <td id="T_b338c588_aabf_11ea_9ed1_84a93e4c419erow3_col2" class="data row3 col2" >$13.62</td>
#             </tr>
#             <tr>
#                         <th id="T_b338c588_aabf_11ea_9ed1_84a93e4c419elevel0_row4" class="row_heading level0 row4" >Iskadarya95</th>
#                         <td id="T_b338c588_aabf_11ea_9ed1_84a93e4c419erow4_col0" class="data row4 col0" >3</td>
#                         <td id="T_b338c588_aabf_11ea_9ed1_84a93e4c419erow4_col1" class="data row4 col1" >$4.37</td>
#                         <td id="T_b338c588_aabf_11ea_9ed1_84a93e4c419erow4_col2" class="data row4 col2" >$13.10</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ---
#
# Most Popular Items
# ------------------------

# %%
## Most Popular Items

### create new dataframe stratified by Item ID and Name

item_strat_data = purchase_data.groupby(["Item ID", "Item Name"])

### pull purchase count

purchase_count_item = item_strat_data["Item Name"].count()

item_price = item_strat_data["Price"].mean()

### pull total purchase 

total_purchase_item = item_strat_data["Price"].sum()

### Create dataframe

item_analysis = pd.DataFrame({"Purchase Count" : purchase_count_item,
                              "Item Price" : item_price,
                              "Total Purchase Value" : total_purchase_item})
### sort     

item_analysis_sorted = item_analysis.sort_values("Purchase Count", ascending = False)

### format output

item_analysis_formatted = item_analysis_sorted.head(5
                                             ).style.set_caption("Top 5 Items by Number Purchased"
                                                   ).format({
                                                            "Item Price" : "${:,.2f}", 
                                                            "Total Purchase Value" : "${:,.2f}"}
                                                   ).set_table_styles(styles)

item_analysis_formatted
# Out:
# <style  type="text/css" >
#     #T_d6a00598_aabf_11ea_bfc1_84a93e4c419e th {
#           font-size: 14px;
#           text-align: Left;
#           font-weight: bold;
#           background-color: #CFCFCF;
#     }    #T_d6a00598_aabf_11ea_bfc1_84a93e4c419e td {
#           font-size: 13px;
#           text-align: Left;
#     }    #T_d6a00598_aabf_11ea_bfc1_84a93e4c419e caption {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#     }</style><table id="T_d6a00598_aabf_11ea_bfc1_84a93e4c419e" ><caption>Top 5 Items by Number Purchased</caption><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d6a00598_aabf_11ea_bfc1_84a93e4c419elevel0_row0" class="row_heading level0 row0" >92</th>
#                         <th id="T_d6a00598_aabf_11ea_bfc1_84a93e4c419elevel1_row0" class="row_heading level1 row0" >Final Critic</th>
#                         <td id="T_d6a00598_aabf_11ea_bfc1_84a93e4c419erow0_col0" class="data row0 col0" >13</td>
#                         <td id="T_d6a00598_aabf_11ea_bfc1_84a93e4c419erow0_col1" class="data row0 col1" >$4.61</td>
#                         <td id="T_d6a00598_aabf_11ea_bfc1_84a93e4c419erow0_col2" class="data row0 col2" >$59.99</td>
#             </tr>
#             <tr>
#                         <th id="T_d6a00598_aabf_11ea_bfc1_84a93e4c419elevel0_row1" class="row_heading level0 row1" >178</th>
#                         <th id="T_d6a00598_aabf_11ea_bfc1_84a93e4c419elevel1_row1" class="row_heading level1 row1" >Oathbreaker, Last Hope of the Breaking Storm</th>
#                         <td id="T_d6a00598_aabf_11ea_bfc1_84a93e4c419erow1_col0" class="data row1 col0" >12</td>
#                         <td id="T_d6a00598_aabf_11ea_bfc1_84a93e4c419erow1_col1" class="data row1 col1" >$4.23</td>
#                         <td id="T_d6a00598_aabf_11ea_bfc1_84a93e4c419erow1_col2" class="data row1 col2" >$50.76</td>
#             </tr>
#             <tr>
#                         <th id="T_d6a00598_aabf_11ea_bfc1_84a93e4c419elevel0_row2" class="row_heading level0 row2" >145</th>
#                         <th id="T_d6a00598_aabf_11ea_bfc1_84a93e4c419elevel1_row2" class="row_heading level1 row2" >Fiery Glass Crusader</th>
#                         <td id="T_d6a00598_aabf_11ea_bfc1_84a93e4c419erow2_col0" class="data row2 col0" >9</td>
#                         <td id="T_d6a00598_aabf_11ea_bfc1_84a93e4c419erow2_col1" class="data row2 col1" >$4.58</td>
#                         <td id="T_d6a00598_aabf_11ea_bfc1_84a93e4c419erow2_col2" class="data row2 col2" >$41.22</td>
#             </tr>
#             <tr>
#                         <th id="T_d6a00598_aabf_11ea_bfc1_84a93e4c419elevel0_row3" class="row_heading level0 row3" >132</th>
#                         <th id="T_d6a00598_aabf_11ea_bfc1_84a93e4c419elevel1_row3" class="row_heading level1 row3" >Persuasion</th>
#                         <td id="T_d6a00598_aabf_11ea_bfc1_84a93e4c419erow3_col0" class="data row3 col0" >9</td>
#                         <td id="T_d6a00598_aabf_11ea_bfc1_84a93e4c419erow3_col1" class="data row3 col1" >$3.22</td>
#                         <td id="T_d6a00598_aabf_11ea_bfc1_84a93e4c419erow3_col2" class="data row3 col2" >$28.99</td>
#             </tr>
#             <tr>
#                         <th id="T_d6a00598_aabf_11ea_bfc1_84a93e4c419elevel0_row4" class="row_heading level0 row4" >108</th>
#                         <th id="T_d6a00598_aabf_11ea_bfc1_84a93e4c419elevel1_row4" class="row_heading level1 row4" >Extraction, Quickblade Of Trembling Hands</th>
#                         <td id="T_d6a00598_aabf_11ea_bfc1_84a93e4c419erow4_col0" class="data row4 col0" >9</td>
#                         <td id="T_d6a00598_aabf_11ea_bfc1_84a93e4c419erow4_col1" class="data row4 col1" >$3.53</td>
#                         <td id="T_d6a00598_aabf_11ea_bfc1_84a93e4c419erow4_col2" class="data row4 col2" >$31.77</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ---
#
# Most Profitable Items
# ------------------------

# %%
### sort     

item_analysis_sorted_by_total = item_analysis.sort_values("Total Purchase Value", ascending = False)

### format output

item_analysis_formatted_sorted_by_total = item_analysis_sorted_by_total.head(5
                                                                      ).style.set_caption("Top 5 Items by Total Purchase Value"
                                                                            ).format({
                                                                                      "Item Price" : "${:,.2f}", 
                                                                                      "Total Purchase Value" : "${:,.2f}"}
                                                                      ).set_table_styles(styles)
item_analysis_formatted_sorted_by_total
# Out:
# <style  type="text/css" >
#     #T_e8d0acae_aabf_11ea_a6ba_84a93e4c419e th {
#           font-size: 14px;
#           text-align: Left;
#           font-weight: bold;
#           background-color: #CFCFCF;
#     }    #T_e8d0acae_aabf_11ea_a6ba_84a93e4c419e td {
#           font-size: 13px;
#           text-align: Left;
#     }    #T_e8d0acae_aabf_11ea_a6ba_84a93e4c419e caption {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#     }</style><table id="T_e8d0acae_aabf_11ea_a6ba_84a93e4c419e" ><caption>Top 5 Items by Total Purchase Value</caption><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e8d0acae_aabf_11ea_a6ba_84a93e4c419elevel0_row0" class="row_heading level0 row0" >92</th>
#                         <th id="T_e8d0acae_aabf_11ea_a6ba_84a93e4c419elevel1_row0" class="row_heading level1 row0" >Final Critic</th>
#                         <td id="T_e8d0acae_aabf_11ea_a6ba_84a93e4c419erow0_col0" class="data row0 col0" >13</td>
#                         <td id="T_e8d0acae_aabf_11ea_a6ba_84a93e4c419erow0_col1" class="data row0 col1" >$4.61</td>
#                         <td id="T_e8d0acae_aabf_11ea_a6ba_84a93e4c419erow0_col2" class="data row0 col2" >$59.99</td>
#             </tr>
#             <tr>
#                         <th id="T_e8d0acae_aabf_11ea_a6ba_84a93e4c419elevel0_row1" class="row_heading level0 row1" >178</th>
#                         <th id="T_e8d0acae_aabf_11ea_a6ba_84a93e4c419elevel1_row1" class="row_heading level1 row1" >Oathbreaker, Last Hope of the Breaking Storm</th>
#                         <td id="T_e8d0acae_aabf_11ea_a6ba_84a93e4c419erow1_col0" class="data row1 col0" >12</td>
#                         <td id="T_e8d0acae_aabf_11ea_a6ba_84a93e4c419erow1_col1" class="data row1 col1" >$4.23</td>
#                         <td id="T_e8d0acae_aabf_11ea_a6ba_84a93e4c419erow1_col2" class="data row1 col2" >$50.76</td>
#             </tr>
#             <tr>
#                         <th id="T_e8d0acae_aabf_11ea_a6ba_84a93e4c419elevel0_row2" class="row_heading level0 row2" >82</th>
#                         <th id="T_e8d0acae_aabf_11ea_a6ba_84a93e4c419elevel1_row2" class="row_heading level1 row2" >Nirvana</th>
#                         <td id="T_e8d0acae_aabf_11ea_a6ba_84a93e4c419erow2_col0" class="data row2 col0" >9</td>
#                         <td id="T_e8d0acae_aabf_11ea_a6ba_84a93e4c419erow2_col1" class="data row2 col1" >$4.90</td>
#                         <td id="T_e8d0acae_aabf_11ea_a6ba_84a93e4c419erow2_col2" class="data row2 col2" >$44.10</td>
#             </tr>
#             <tr>
#                         <th id="T_e8d0acae_aabf_11ea_a6ba_84a93e4c419elevel0_row3" class="row_heading level0 row3" >145</th>
#                         <th id="T_e8d0acae_aabf_11ea_a6ba_84a93e4c419elevel1_row3" class="row_heading level1 row3" >Fiery Glass Crusader</th>
#                         <td id="T_e8d0acae_aabf_11ea_a6ba_84a93e4c419erow3_col0" class="data row3 col0" >9</td>
#                         <td id="T_e8d0acae_aabf_11ea_a6ba_84a93e4c419erow3_col1" class="data row3 col1" >$4.58</td>
#                         <td id="T_e8d0acae_aabf_11ea_a6ba_84a93e4c419erow3_col2" class="data row3 col2" >$41.22</td>
#             </tr>
#             <tr>
#                         <th id="T_e8d0acae_aabf_11ea_a6ba_84a93e4c419elevel0_row4" class="row_heading level0 row4" >103</th>
#                         <th id="T_e8d0acae_aabf_11ea_a6ba_84a93e4c419elevel1_row4" class="row_heading level1 row4" >Singed Scalpel</th>
#                         <td id="T_e8d0acae_aabf_11ea_a6ba_84a93e4c419erow4_col0" class="data row4 col0" >8</td>
#                         <td id="T_e8d0acae_aabf_11ea_a6ba_84a93e4c419erow4_col1" class="data row4 col1" >$4.35</td>
#                         <td id="T_e8d0acae_aabf_11ea_a6ba_84a93e4c419erow4_col2" class="data row4 col2" >$34.80</td>
#             </tr>
#     </tbody></table>
